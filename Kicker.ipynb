# %%
# === Requirements ===
# pip install pandas numpy scikit-learn xgboost

import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.model_selection import train_test_split

# -----------------------------
# Config
# -----------------------------
CSV_PATH = "/Users/shouryasoni/Desktop/AI Data Lab/nfl_kick_attempts(in).csv"
USE_ONLY_FIELD_GOALS = True         # exclude extra points from EPA calc
MIN_ROOKIE_ATTEMPTS = 1             # set to 10+ if you want stability filtering
DISTANCE_BINS = [0, 19, 29, 39, 49, np.inf]  # yards
MIN_ROOKIE_ATTEMPTS = 20 
# League-average FG make% by bin (very rough priors; adjust if you have better rates)
BIN_FG_PROB = [0.99, 0.95, 0.87, 0.75, 0.6]
BIN_EP = [p * 3.0 for p in BIN_FG_PROB]      # Expected points = P(make)*3

# -----------------------------
# Load
# -----------------------------
df = pd.read_csv(CSV_PATH)

# Basic hygiene
# Ensure lowercase standardized column names if needed (uncomment if your file differs)
# df.columns = [c.strip().lower() for c in df.columns]

# Remove all rows from season 1999
if "season" in df.columns:
    df = df[df["season"] != 1999].copy()

# Keep only rows with a numeric distance (needed for EP by distance)
df = df.copy()
df = df[pd.to_numeric(df["kick_distance"], errors="coerce").notna()]
df["kick_distance"] = df["kick_distance"].astype(float)

# Optionally keep only field-goal attempts (exclude extra points)
# Assumes extra_point column is 1 for XP, 0 for not XP; adjust if needed
if USE_ONLY_FIELD_GOALS and "extra_point" in df.columns:
    df = df[df["extra_point"] == 0].copy()

# -----------------------------
# Per-kick EPA
# -----------------------------
# Bin distance and map to expected points
df["distance_bin"] = pd.cut(
    df["kick_distance"], bins=DISTANCE_BINS, right=True, labels=False, include_lowest=True
)

# If a kick falls outside bins, set to NaN (shouldn't happen with np.inf)
df["expected_points"] = df["distance_bin"].apply(
    lambda ix: BIN_EP[int(ix)] if pd.notnull(ix) else np.nan
)

# Actual points: 3 for made FG, else 0
# (for extra points you’d use 1 point if you decide to include them; we excluded XP above)
df["actual_points"] = (df["made"].astype(int) * 3).astype(float)

# EPA = actual - expected
df["epa"] = df["actual_points"] - df["expected_points"]

# -----------------------------
# Rookie-season identification
# -----------------------------
# First season a kicker appears in the data is treated as rookie season
first_season = (
    df.groupby("kicker_player_id")["season"]
    .min()
    .rename("rookie_season")
    .reset_index()
)

df = df.merge(first_season, on="kicker_player_id", how="left")
rookie_df = df[df["season"] == df["rookie_season"]].copy()

# -----------------------------
# Rookie-year feature engineering
# -----------------------------
# Precompute masks for feature rates
rookie_df["is_clutch"] = rookie_df["score_differential"].abs() <= 3
rookie_df["is_50_plus"] = rookie_df["kick_distance"] >= 50

agg = rookie_df.groupby(["kicker_player_id", "kicker_player_name", "rookie_season"]).agg(
    attempts=("made", "size"),
    makes=("made", "sum"),
    avg_distance=("kick_distance", "mean"),
    long_attempts=("is_50_plus", "sum"),
    long_makes=("made", lambda x: x[rookie_df.loc[x.index, "is_50_plus"]].sum()),
    clutch_attempts=("is_clutch", "sum"),
    clutch_makes=("made", lambda x: x[rookie_df.loc[x.index, "is_clutch"]].sum()),
    total_epa=("epa", "sum"),
)

# Rates
agg["fg_pct"] = np.where(agg["attempts"] > 0, agg["makes"] / agg["attempts"], np.nan)
agg["epa_per_kick"] = np.where(agg["attempts"] > 0, agg["total_epa"] / agg["attempts"], np.nan)
agg["long_fg_pct"] = np.where(agg["long_attempts"] > 0, agg["long_makes"] / agg["long_attempts"], np.nan)
agg["clutch_fg_pct"] = np.where(agg["clutch_attempts"] > 0, agg["clutch_makes"] / agg["clutch_attempts"], np.nan)

rookies = agg.reset_index()

# Optional stability filter (e.g., keep rookies with >= MIN_ROOKIE_ATTEMPTS attempts)
rookies = rookies[rookies["attempts"] >= MIN_ROOKIE_ATTEMPTS].copy()

# -----------------------------
# Define success label
# -----------------------------
# Success = above-median rookie EPA per kick (change to total_epa if you prefer)
median_epa_per_kick = rookies["epa_per_kick"].median(skipna=True)
rookies["successful"] = (rookies["epa_per_kick"] >= median_epa_per_kick).astype(int)

# -----------------------------
# Modeling dataset
# -----------------------------
feature_cols = ["fg_pct", "avg_distance", "long_fg_pct", "clutch_fg_pct", "attempts"]

# Replace inf/NaN in features (simple imputation: fill NaN long/clutch pct with overall fg_pct or 0)
X = rookies[feature_cols].copy()
# For missing long/clutch %, fall back to fg_pct or 0 if fg_pct also missing
X["long_fg_pct"] = X["long_fg_pct"].fillna(X["fg_pct"])
X["clutch_fg_pct"] = X["clutch_fg_pct"].fillna(X["fg_pct"])
X = X.fillna(0.0)

y = rookies["successful"].astype(int)

# Train/test split for quick validation of the signal
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# -----------------------------
# Logistic Regression
# -----------------------------
# Use liblinear for small datasets; increase C if you want less regularization
clf = LogisticRegression(solver="liblinear", C=1.0, max_iter=1000)
clf.fit(X_train, y_train)

y_prob = clf.predict_proba(X_test)[:, 1]
y_pred = (y_prob >= 0.5).astype(int)

print("=== Classification Report (threshold=0.5) ===")
print(classification_report(y_test, y_pred, digits=3))
try:
    print("AUC:", roc_auc_score(y_test, y_prob))
except Exception:
    pass

# -----------------------------
# Coefficients (feature importance in log-odds space)
# -----------------------------
coef_df = pd.DataFrame(
    {"feature": feature_cols, "coef": clf.coef_.ravel()}
).sort_values("coef", ascending=False)
print("\n=== Logistic Regression Coefficients (log-odds) ===")
print(coef_df.to_string(index=False))

# -----------------------------
# Attach predicted success probability to each rookie (optional)
# -----------------------------
rookies_out = rookies.copy()
rookies_out["p_success"] = clf.predict_proba(X)[:, 1]

# Top and bottom examples (optional)
print("\n=== Top 10 rookies by predicted success probability ===")
print(
    rookies_out.sort_values("p_success", ascending=False)[
        ["kicker_player_name", "rookie_season", "epa_per_kick", "fg_pct", "avg_distance",
         "long_fg_pct", "clutch_fg_pct", "attempts", "p_success", "successful"]
    ].head(10).to_string(index=False)
)

print("\n=== Bottom 10 rookies by predicted success probability ===")
print(
    rookies_out.sort_values("p_success", ascending=True)[
        ["kicker_player_name", "rookie_season", "epa_per_kick", "fg_pct", "avg_distance",
         "long_fg_pct", "clutch_fg_pct", "attempts", "p_success", "successful"]
    ].head(10).to_string(index=False)
)
# Out:
# === Classification Report (threshold=0.5) ===
#               precision    recall  f1-score   support
#
#            0      0.875     0.583     0.700        12
#            1      0.688     0.917     0.786        12
#
#     accuracy                          0.750        24
#    macro avg      0.781     0.750     0.743        24
# weighted avg      0.781     0.750     0.743        24
#
# AUC: 0.7152777777777777
#
# === Logistic Regression Coefficients (log-odds) ===
#       feature      coef
#        fg_pct  1.054370
# clutch_fg_pct  0.937108
#   long_fg_pct  0.727937
#      attempts  0.054580
#  avg_distance -0.074934
#
# === Top 10 rookies by predicted success probability ===
# kicker_player_name  rookie_season  epa_per_kick   fg_pct  avg_distance  long_fg_pct  clutch_fg_pct  attempts  p_success  successful
#           B.Aubrey           2023      0.426316 0.947368     37.842105     1.000000       1.000000        38   0.753040           1
#           H.Butker           2017      0.257857 0.904762     37.214286     0.800000       0.882353        42   0.746399           1
#           J.Nedney           2000      0.122368 0.894737     33.473684     0.666667       0.909091        38   0.742481           1
#           M.Stover           2000      0.181538 0.897436     35.461538     0.666667       1.000000        39   0.741267           1
#           C.Parkey           2014      0.140000 0.888889     35.416667     1.000000       0.909091        36   0.738971           1
#            B.Walsh           2012      0.388421 0.921053     39.342105     1.000000       1.000000        38   0.726064           1
#        A.Del Greco           2000     -0.141818 0.818182     32.515152     1.000000       0.850000        33   0.723998           0
#           M.Bryant           2002     -0.202500 0.812500     32.562500          NaN       1.000000        32   0.711841           0
#            D.Akers           2000      0.105455 0.878788     35.757576     1.000000       0.941176        33   0.704903           1
#          C.Boswell           2015      0.215625 0.906250     36.218750     1.000000       0.909091        32   0.685790           1
#
# === Bottom 10 rookies by predicted success probability ===
# kicker_player_name  rookie_season  epa_per_kick   fg_pct  avg_distance  long_fg_pct  clutch_fg_pct  attempts  p_success  successful
#           W.Richey           2000     -0.505909 0.681818     35.772727     0.000000       0.571429        22   0.266419           0
#           J.Arians           2001     -0.775714 0.571429     37.904762          NaN       0.500000        21   0.270009           0
#            D.Brien           2000     -0.050690 0.793103     36.793103     0.000000       0.333333        29   0.307240           0
#           C.Ryland           2023     -0.454800 0.640000     40.760000     0.500000       0.727273        25   0.319314           0
#        C.Blanchard           2000     -0.340435 0.695652     37.826087     0.500000       0.555556        23   0.321154           0
#         Z.Gonzalez           2017     -0.190500 0.750000     38.200000     0.666667       0.636364        20   0.334949           0
#          N.Rackers           2000     -0.832857 0.571429     35.714286          NaN       0.666667        21   0.337546           0
#            L.Tynes           2004     -0.210000 0.739130     37.869565     0.500000       0.700000        23   0.361114           0
#            J.Brown           2003     -0.237000 0.733333     39.700000     0.333333       0.636364        30   0.374561           0
#           J.Carney           2000     -0.212609 0.739130     38.347826     0.500000       0.800000        23   0.374571           0

# %%
import xgboost as xgb

# %%
xgb_clf = xgb.XGBClassifier(
    use_label_encoder=False,
    eval_metric="logloss",
    n_estimators=200,
    max_depth=3,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

xgb_clf.fit(X_train, y_train)

y_prob_xgb = xgb_clf.predict_proba(X_test)[:, 1]
y_pred_xgb = (y_prob_xgb >= 0.5).astype(int)

print("=== XGBoost Classification Report (threshold=0.5) ===")
print(classification_report(y_test, y_pred_xgb, digits=3))
try:
    print("AUC:", roc_auc_score(y_test, y_prob_xgb))
except Exception:
    pass

fi = pd.DataFrame({
    "feature": X.columns,
    "importance": xgb_clf.feature_importances_
}).sort_values("importance", ascending=False)

print("\n=== XGBoost Feature Importances ===")
print(fi.to_string(index=False))

rookies_out["p_success_xgb"] = xgb_clf.predict_proba(X)[:, 1]

print("\n=== Top 10 rookies by XGBoost predicted success probability ===")
print(
    rookies_out.sort_values("p_success_xgb", ascending=False)[
        ["kicker_player_name", "rookie_season", "epa_per_kick", "fg_pct", "avg_distance",
         "long_fg_pct", "clutch_fg_pct", "attempts", "p_success_xgb", "successful"]
    ].head(10).to_string(index=False)
)

print("\n=== Bottom 10 rookies by XGBoost predicted success probability ===")
print(
    rookies_out.sort_values("p_success_xgb", ascending=True)[
        ["kicker_player_name", "rookie_season", "epa_per_kick", "fg_pct", "avg_distance",
         "long_fg_pct", "clutch_fg_pct", "attempts", "p_success_xgb", "successful"]
    ].head(10).to_string(index=False)
)
# Out:
# /Users/shouryasoni/anaconda3/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [18:29:25] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_7eg2b3w9sf/croot/xgboost-split_1749630922962/work/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# === XGBoost Classification Report (threshold=0.5) ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.917     0.957        12
#            1      0.923     1.000     0.960        12
#
#     accuracy                          0.958        24
#    macro avg      0.962     0.958     0.958        24
# weighted avg      0.962     0.958     0.958        24
#
# AUC: 1.0
#
# === XGBoost Feature Importances ===
#       feature  importance
#        fg_pct    0.564366
#  avg_distance    0.169499
# clutch_fg_pct    0.123349
#      attempts    0.080137
#   long_fg_pct    0.062648
#
# === Top 10 rookies by XGBoost predicted success probability ===
# kicker_player_name  rookie_season  epa_per_kick   fg_pct  avg_distance  long_fg_pct  clutch_fg_pct  attempts  p_success_xgb  successful
#        E.McPherson           2021      0.267273 0.848485     41.818182     0.818182       0.800000        33       0.995133           1
#          J.Elliott           2017      0.175161 0.838710     40.258065     0.833333       0.800000        31       0.993702           1
#            J.Bates           2024      0.377586 0.896552     41.620690     0.750000       1.000000        29       0.992800           1
#           J.Tucker           2012      0.299091 0.909091     39.242424     1.000000       0.882353        33       0.992086           1
#            B.Walsh           2012      0.388421 0.921053     39.342105     1.000000       1.000000        38       0.991737           1
#        C.Catanzaro           2014      0.183636 0.878788     38.212121     0.666667       0.857143        33       0.989906           1
#           H.Butker           2017      0.257857 0.904762     37.214286     0.800000       0.882353        42       0.989906           1
#            J.Karty           2024      0.101471 0.852941     37.882353     0.857143       0.933333        34       0.989461           1
#           B.Aubrey           2023      0.426316 0.947368     37.842105     1.000000       1.000000        38       0.989461           1
#           C.Little           2024      0.396207 0.931034     38.413793     0.833333       1.000000        29       0.988604           1
#
# === Bottom 10 rookies by XGBoost predicted success probability ===
# kicker_player_name  rookie_season  epa_per_kick   fg_pct  avg_distance  long_fg_pct  clutch_fg_pct  attempts  p_success_xgb  successful
#           J.Scobee           2004     -0.205161 0.774194     35.225806     0.333333       0.888889        31       0.009225           0
#           S.Marler           2003     -0.691818 0.606061     35.878788     0.500000       0.461538        33       0.010048           0
#            T.Seder           2000     -0.236364 0.757576     36.333333     0.000000       0.714286        33       0.011035           0
#          B.Daluiso           2000     -0.366522 0.739130     33.391304          NaN       0.900000        23       0.011504           0
#          A. Elling           2003     -0.319200 0.720000     36.800000     0.333333       0.714286        25       0.011580           0
#           W.Richey           2000     -0.505909 0.681818     35.772727     0.000000       0.571429        22       0.011755           0
#          N.Rackers           2000     -0.832857 0.571429     35.714286          NaN       0.666667        21       0.011830           0
#           J.Cortez           2001     -0.398400 0.720000     34.160000     1.000000       0.785714        25       0.012742           0
#       S.Gostkowski           2006     -0.317308 0.769231     32.692308     1.000000       0.888889        26       0.012885           0
#         S.Christie           2000     -0.381818 0.727273     34.212121     0.000000       0.818182        33       0.013272           0

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(
    n_estimators=200,
    max_depth=6,
    random_state=42,
    n_jobs=-1
)

rf_clf.fit(X_train, y_train)

y_prob_rf = rf_clf.predict_proba(X_test)[:, 1]
y_pred_rf = (y_prob_rf >= 0.5).astype(int)

print("=== Random Forest Classification Report (threshold=0.5) ===")
print(classification_report(y_test, y_pred_rf, digits=3))
try:
    print("AUC:", roc_auc_score(y_test, y_prob_rf))
except Exception:
    pass

fi_rf = pd.DataFrame({
    "feature": X.columns,
    "importance": rf_clf.feature_importances_
}).sort_values("importance", ascending=False)

print("\n=== Random Forest Feature Importances ===")
print(fi_rf.to_string(index=False))

# attach RF predicted probabilities to output table
rookies_out["p_success_rf"] = rf_clf.predict_proba(X)[:, 1]

print("\n=== Top 10 rookies by RF predicted success probability ===")
print(
    rookies_out.sort_values("p_success_rf", ascending=False)[
        ["kicker_player_name", "rookie_season", "epa_per_kick", "fg_pct", "avg_distance",
         "long_fg_pct", "clutch_fg_pct", "attempts", "p_success_rf", "successful"]
    ].head(10).to_string(index=False)
)

print("\n=== Bottom 10 rookies by RF predicted success probability ===")
print(
    rookies_out.sort_values("p_success_rf", ascending=True)[
        ["kicker_player_name", "rookie_season", "epa_per_kick", "fg_pct", "avg_distance",
         "long_fg_pct", "clutch_fg_pct", "attempts", "p_success_rf", "successful"]
    ].head(10).to_string(index=False)
)
# Out:
# === Random Forest Classification Report (threshold=0.5) ===
#               precision    recall  f1-score   support
#
#            0      1.000     0.917     0.957        12
#            1      0.923     1.000     0.960        12
#
#     accuracy                          0.958        24
#    macro avg      0.962     0.958     0.958        24
# weighted avg      0.962     0.958     0.958        24
#
# AUC: 1.0
#
# === Random Forest Feature Importances ===
#       feature  importance
#        fg_pct    0.553887
#  avg_distance    0.161470
# clutch_fg_pct    0.143583
#      attempts    0.077128
#   long_fg_pct    0.063932
#
# === Top 10 rookies by RF predicted success probability ===
# kicker_player_name  rookie_season  epa_per_kick   fg_pct  avg_distance  long_fg_pct  clutch_fg_pct  attempts  p_success_rf  successful
#        E.McPherson           2021      0.267273 0.848485     41.818182     0.818182       0.800000        33      1.000000           1
#           J.Tucker           2012      0.299091 0.909091     39.242424     1.000000       0.882353        33      1.000000           1
#        C.Catanzaro           2014      0.183636 0.878788     38.212121     0.666667       0.857143        33      0.997143           1
#           B.Aubrey           2023      0.426316 0.947368     37.842105     1.000000       1.000000        38      0.995000           1
#            B.Walsh           2012      0.388421 0.921053     39.342105     1.000000       1.000000        38      0.995000           1
#            J.Bates           2024      0.377586 0.896552     41.620690     0.750000       1.000000        29      0.995000           1
#           C.Little           2024      0.396207 0.931034     38.413793     0.833333       1.000000        29      0.990000           1
#            J.Karty           2024      0.101471 0.852941     37.882353     0.857143       0.933333        34      0.990000           1
#           M.Stover           2000      0.181538 0.897436     35.461538     0.666667       1.000000        39      0.990000           1
#           M.Hollis           2000      0.298846 0.923077     36.923077     1.000000       1.000000        26      0.989444           1
#
# === Bottom 10 rookies by RF predicted success probability ===
# kicker_player_name  rookie_season  epa_per_kick   fg_pct  avg_distance  long_fg_pct  clutch_fg_pct  attempts  p_success_rf  successful
#           J.Arians           2001     -0.775714 0.571429     37.904762          NaN       0.500000        21      0.000000           0
#        C.Blanchard           2000     -0.340435 0.695652     37.826087     0.500000       0.555556        23      0.000000           0
#          B.Daluiso           2000     -0.366522 0.739130     33.391304          NaN       0.900000        23      0.001000           0
#           J.Cortez           2001     -0.398400 0.720000     34.160000     1.000000       0.785714        25      0.006875           0
#            L.Tynes           2004     -0.210000 0.739130     37.869565     0.500000       0.700000        23      0.010000           0
#            J.Brown           2003     -0.237000 0.733333     39.700000     0.333333       0.636364        30      0.010000           0
#             J.Hall           2000     -0.497812 0.656250     37.593750     0.333333       0.666667        32      0.010000           0
#       S.Janikowski           2000     -0.345000 0.687500     38.281250     0.250000       0.615385        32      0.015000           0
#          C.Sturgis           2013     -0.082059 0.764706     39.529412     0.428571       0.722222        34      0.015000           0
#          R.Bullock           2013     -0.149143 0.742857     39.200000     0.200000       0.583333        35      0.015000           0

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# use existing rookies_out and model probability columns:
df = rookies_out.copy()

models = [
    ("p_success", "Logistic Regression"),
    ("p_success_xgb", "XGBoost"),
    ("p_success_rf", "Random Forest"),
]

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 14))
plt.subplots_adjust(hspace=0.45, wspace=0.35)
sns.set_style("whitegrid")

for i, (col, name) in enumerate(models):
    # prepare top 10 and bottom 10, add display label (name + rookie season)
    top10 = df.nlargest(10, col).copy()
    bot10 = df.nsmallest(10, col).copy()
    top10["label"] = top10["kicker_player_name"] + " (" + top10["rookie_season"].astype(str) + ")"
    bot10["label"] = bot10["kicker_player_name"] + " (" + bot10["rookie_season"].astype(str) + ")"

    # Top 10 (horizontal bar chart)
    ax_top = axes[i, 0]
    top10_plot = top10.sort_values(col, ascending=True)  # ascending so largest on top visually
    sns.barplot(x=col, y="label", data=top10_plot, ax=ax_top, palette="Greens_r")
    ax_top.set_xlim(0, 1)
    ax_top.set_title(f"{name} — Top 10 by predicted probability")
    ax_top.set_xlabel("Predicted probability")
    ax_top.set_ylabel("")
    for p, prob in enumerate(top10_plot[col].values):
        ax_top.text(prob + 0.01, p, f"{prob:.3f}", va="center", fontsize=9)

    # Bottom 10 (horizontal bar chart)
    ax_bot = axes[i, 1]
    bot10_plot = bot10.sort_values(col, ascending=False)  # descending so smallest on top visually
    sns.barplot(x=col, y="label", data=bot10_plot, ax=ax_bot, palette="Reds")
    ax_bot.set_xlim(0, 1)
    ax_bot.set_title(f"{name} — Bottom 10 by predicted probability")
    ax_bot.set_xlabel("Predicted probability")
    ax_bot.set_ylabel("")
    for p, prob in enumerate(bot10_plot[col].values):
        ax_bot.text(prob + 0.01, p, f"{prob:.3f}", va="center", fontsize=9)

plt.tight_layout()
plt.show()

from matplotlib_venn import venn3
import matplotlib.pyplot as plt

df["id"] = df["kicker_player_name"] + " (" + df["rookie_season"].astype(str) + ")"

# -------- TOP 10 SETS --------
top10_lr  = set(df.nlargest(10, "p_success")["id"])
top10_xgb = set(df.nlargest(10, "p_success_xgb")["id"])
top10_rf  = set(df.nlargest(10, "p_success_rf")["id"])

# -------- BOTTOM 10 SETS --------
bot10_lr  = set(df.nsmallest(10, "p_success")["id"])
bot10_xgb = set(df.nsmallest(10, "p_success_xgb")["id"])
bot10_rf  = set(df.nsmallest(10, "p_success_rf")["id"])


# ---------- TOP 10 VENN WITH NAMES ----------
plt.figure(figsize=(10,10))
v = venn3([top10_lr, top10_xgb, top10_rf],
          set_labels=("Logistic", "XGBoost", "Random Forest"))

regions_top = {
    "100": top10_lr - top10_xgb - top10_rf,
    "010": top10_xgb - top10_lr - top10_rf,
    "001": top10_rf - top10_lr - top10_xgb,
    "110": (top10_lr & top10_xgb) - top10_rf,
    "101": (top10_lr & top10_rf) - top10_xgb,
    "011": (top10_xgb & top10_rf) - top10_lr,
    "111": top10_lr & top10_xgb & top10_rf
}

for code, names in regions_top.items():
    label = v.get_label_by_id(code)
    if label:
        label.set_text("\n".join(names))

plt.title("Top 10 Overlap")
plt.show()


# ---------- BOTTOM 10 VENN WITH NAMES ----------
plt.figure(figsize=(10,10))
v = venn3([bot10_lr, bot10_xgb, bot10_rf],
          set_labels=("Logistic", "XGBoost", "Random Forest"))

regions_bot = {
    "100": bot10_lr - bot10_xgb - bot10_rf,
    "010": bot10_xgb - bot10_lr - bot10_rf,
    "001": bot10_rf - bot10_lr - bot10_xgb,
    "110": (bot10_lr & bot10_xgb) - bot10_rf,
    "101": (bot10_lr & bot10_rf) - bot10_xgb,
    "011": (bot10_xgb & bot10_rf) - bot10_lr,
    "111": bot10_lr & bot10_xgb & bot10_rf
}

for code, names in regions_bot.items():
    label = v.get_label_by_id(code)
    if label:
        label.set_text("\n".join(names))

plt.title("Bottom 10 Overlap")
plt.show()


# ---------- PRINT NAMES (unchanged from your version) ----------
print("\n=== TOP 10 OVERLAPS ===")
print("All 3:", top10_lr & top10_xgb & top10_rf)
print("LR ∩ XGB:", (top10_lr & top10_xgb) - top10_rf)
print("LR ∩ RF :", (top10_lr & top10_rf)  - top10_xgb)
print("XGB ∩ RF:", (top10_xgb & top10_rf) - top10_lr)

print("\n=== BOTTOM 10 OVERLAPS ===")
print("All 3:", bot10_lr & bot10_xgb & bot10_rf)
print("LR ∩ XGB:", (bot10_lr & bot10_xgb) - bot10_rf)
print("LR ∩ RF :", (bot10_lr & bot10_rf)  - bot10_xgb)
print("XGB ∩ RF:", (bot10_xgb & bot10_rf) - bot10_lr)
# Out:
# /var/folders/0d/lddk8ll133lfbm4q2tyf5qsh0000gn/T/ipykernel_18880/682044646.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y="label", data=top10_plot, ax=ax_top, palette="Greens_r")
# /var/folders/0d/lddk8ll133lfbm4q2tyf5qsh0000gn/T/ipykernel_18880/682044646.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y="label", data=bot10_plot, ax=ax_bot, palette="Reds")
# /var/folders/0d/lddk8ll133lfbm4q2tyf5qsh0000gn/T/ipykernel_18880/682044646.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y="label", data=top10_plot, ax=ax_top, palette="Greens_r")
# /var/folders/0d/lddk8ll133lfbm4q2tyf5qsh0000gn/T/ipykernel_18880/682044646.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y="label", data=bot10_plot, ax=ax_bot, palette="Reds")
# /var/folders/0d/lddk8ll133lfbm4q2tyf5qsh0000gn/T/ipykernel_18880/682044646.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y="label", data=top10_plot, ax=ax_top, palette="Greens_r")
# /var/folders/0d/lddk8ll133lfbm4q2tyf5qsh0000gn/T/ipykernel_18880/682044646.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=col, y="label", data=bot10_plot, ax=ax_bot, palette="Reds")
# === TOP 10 OVERLAPS ===
# All 3: {'B.Aubrey (2023)', 'B.Walsh (2012)'}
# LR ∩ XGB: {'H.Butker (2017)'}
# LR ∩ RF : {'M.Stover (2000)'}
# XGB ∩ RF: {'J.Karty (2024)', 'J.Bates (2024)', 'J.Tucker (2012)', 'C.Catanzaro (2014)', 'C.Little (2024)', 'E.McPherson (2021)'}
#
# === BOTTOM 10 OVERLAPS ===
# All 3: {'N.Rackers (2000)'}
# LR ∩ XGB: {'W.Richey (2000)'}
# LR ∩ RF : {'J.Arians (2001)', 'J.Brown (2003)', 'C.Blanchard (2000)', 'L.Tynes (2004)'}
# XGB ∩ RF: {'J.Cortez (2001)', 'B.Daluiso (2000)'}
